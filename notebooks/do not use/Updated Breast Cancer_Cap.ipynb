# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
death_rate = pd.read_csv('../data/2015-2020 death.csv')

# %%
death_rate
# Out:
#                 County   FIPS Met Healthy People Objective of 15.3?  \
# 0            Tennessee  47000                                    No
# 1        United States      0                                    No
# 2      Crockett County  47033                                    No
# 3        Unicoi County  47171                                    No
# 4         Scott County  47151                                    No
# ..                 ...    ...                                   ...
# 286       Wayne County  47181                                   ***
# 287     Weakley County  47183                                   ***
# 288       White County  47185                                   ***
# 289  Williamson County  47187                                   ***
# 290      Wilson County  47189                                   ***
#
#      Age-Adjusted Death Rate([rate note]) - deaths per 100,000       Race  \
# 0                                                 21.6          All races
# ...

# %%
death_rate = death_rate.rename(columns={'Age-Adjusted Death Rate([rate note]) - deaths per 100,000' : 'Age-Adjusted Death Rate'})

# %%
death_rate
# Out:
#                 County   FIPS Met Healthy People Objective of 15.3?  \
# 0            Tennessee  47000                                    No
# 1        United States      0                                    No
# 2      Crockett County  47033                                    No
# 3        Unicoi County  47171                                    No
# 4         Scott County  47151                                    No
# ..                 ...    ...                                   ...
# 286       Wayne County  47181                                   ***
# 287     Weakley County  47183                                   ***
# 288       White County  47185                                   ***
# 289  Williamson County  47187                                   ***
# 290      Wilson County  47189                                   ***
#
#      Age-Adjusted Death Rate       Race Lower CI (Rate) Upper CI (Rate)  \
# 0                       21.6  All races              21            22.2
# ...

# %%
death_rate = death_rate.rename(columns={'County' : 'county'})

# %%
death_rate
# Out:
#                 county   FIPS Met Healthy People Objective of 15.3?  \
# 0            Tennessee  47000                                    No
# 1        United States      0                                    No
# 2      Crockett County  47033                                    No
# 3        Unicoi County  47171                                    No
# 4         Scott County  47151                                    No
# ..                 ...    ...                                   ...
# 286       Wayne County  47181                                   ***
# 287     Weakley County  47183                                   ***
# 288       White County  47185                                   ***
# 289  Williamson County  47187                                   ***
# 290      Wilson County  47189                                   ***
#
#      Age-Adjusted Death Rate       Race Lower CI (Rate) Upper CI (Rate)  \
# 0                       21.6  All races              21            22.2
# ...

# %% [markdown]
# animals_slaughtered.rename(columns={"" : ""})

# %%
insurance = pd.read_csv('../data/acs-2015-2020.csv')

# %%
insurance
# Out:
#                 county  Year  EMPLOYMENT STATS - Ages 16 yrs+   \
# 0         Meigs County  2020                            10,036
# 1    Montgomery County  2020                           155,404
# 2         Moore County  2020                             5,321
# 3         Obion County  2020                            24,444
# 4       Overton County  2020                            17,912
# ..                 ...   ...                               ...
# 470     Bledsoe County  2016                            11,648
# 471    Campbell County  2016                            32,827
# 472      Cannon County  2016                            11,283
# 473     Houston County  2016                             6,603
# 474       Maury County  2016                            67,419
#
#      EMPLOYMENT STATS - Ages 16 yrs+ - In labor force   \
# 0                                                5,162
# 1                                              103,722
# ...

# %%
mammogram = pd.read_excel('../data/Mammogram Facilities.xlsx')

# %%
mammogram
# Out:
#                        facility             phone number              city  \
# 0     Premier Radiology Antioch           (615) 467-4642       Antioch, TN
# 1     Starr Regional Breast Cen     (423) 744-3372 x3373        Athens, TN
# 2      Saint Francis Hospital -           (901) 820-7575      Bartlett, TN
# 3     Memphis OB/GYN Associatio           (901) 373-9221      Bartlett, TN
# 4     West Tennessee Healthcare           (731) 659-0243       Bolivar, TN
# ..                          ...                      ...               ...
# 187   Baptist Memorial Hospital     (731) 884-8550 x8553    Union City, TN
# 188   Ascension Saint Thomas Th           (931) 296-0298       Waverly, TN
# 189        Wayne Medical Center     (931) 722-5411 x2060    Waynesboro, TN
# 190   Woman's Center of STRHS-W           (931) 967-8258    Winchester, TN
# 191   Saint Thomas Stones River           (615) 563-7229      Woodbury, TN
#
#     zip code       County Name
# 0      37013   Davidson County
# ...

# %%
mammogram.groupby(['County Name']).agg({'zip code': ['count']})
# Out:
#                               zip code
#                                  count
# County Name
# Anderson County; Roane County        1
# Bedford County                       1
# Benton County                        1
# Bledsoe County                       1
# Blount County                        2
# ...                                ...
# Williamson County                    7
# Wilson County                        5
#  Montgomery County                   2
#  Warren County                       1
#  Washington County                   5
#
# [72 rows x 1 columns]

# %%
coverage = pd.read_csv('../data/2015-2020_ACS_Insurance.csv',  encoding='cp1252')

# %%
coverage
# Out:
#                 county  Year    Total population    Total population - Male   \
# 0         Meigs County   2020               12129                       5982
# 1    Montgomery County   2020              191007                      90431
# 2         Moore County   2020                6302                       3105
# 3         Obion County   2020               29900                      14372
# 4       Overton County   2020               21876                      10700
# ..                 ...    ...                 ...                        ...
# 470     Bledsoe County   2016               12884                        987
# 471    Campbell County   2016               39509                       2957
# 472      Cannon County   2016               13666                       1137
# 473     Houston County   2016                8037                        580
# 474       Maury County   2016               84594                       6653
#
# ...

# %%
coverage.columns = coverage.columns.str.strip()

# %% [markdown]
# Merging Death Rate with the Coverage DFs to try and create a correlation graph.

# %%
death_coverage = death_rate.merge(coverage, on=['county'], how ='outer')

# %%
death_coverage
# Out:
#                  county   FIPS Met Healthy People Objective of 15.3?  \
# 0             Tennessee  47000                                    No
# 1             Tennessee  47000                                    No
# 2             Tennessee  47000                                    No
# 3         United States      0                                    No
# 4         United States      0                                    No
# ...                 ...    ...                                   ...
# 1426       Wayne County  47181                                   ***
# 1427       Wayne County  47181                                   ***
# 1428       Wayne County  47181                                   ***
# 1429       Wayne County  47181                                   ***
# 1430  United States (6)      0                                    No
#
#       Age-Adjusted Death Rate       Race Lower CI (Rate) Upper CI (Rate)  \
# ...

# %%
death_coverage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1431 entries, 0 to 1430
# Data columns (total 81 columns):
#  #   Column                                                                               Non-Null Count  Dtype
# ---  ------                                                                               --------------  -----
#  0   county                                                                               1431 non-null   object
#  1    FIPS                                                                                1431 non-null   int64
#  2   Met Healthy People Objective of 15.3?                                                1431 non-null   object
#  3   Age-Adjusted Death Rate                                                              711 non-null    float64
#  4   Race                                                                                 1431 non-null   object
# ...

# %%
death_coverage.columns = death_coverage.columns.str.strip()

# %%
death_coverage1 = death_coverage[['county', 'Age-Adjusted Death Rate', 'Race', 'Total – Insured Population (Female)', 'Total – Uninsured Population (Female)']]

# %% [markdown]
#  gourds.replace(to_replace='EXH', value=np.NaN) gourds = gourds.replace(to_replace='DMG', value=np.NaN)

# %%
death_coverage1
# Out:
#                  county  Age-Adjusted Death Rate       Race  \
# 0             Tennessee                     21.6  All races
# 1             Tennessee                     20.7      White
# 2             Tennessee                     29.1      Black
# 3         United States                     19.6  All races
# 4         United States                     27.6      Black
# ...                 ...                      ...        ...
# 1426       Wayne County                      NaN      Black
# 1427       Wayne County                      NaN      Black
# 1428       Wayne County                      NaN      Black
# 1429       Wayne County                      NaN      Black
# 1430  United States (6)                     19.7      White
#
#       Total – Insured Population (Female)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# ...

# %%
death_coverage1 = death_coverage1.replace(to_replace='Tennessee', value=np.NaN)

# %%
death_coverage1 = death_coverage1.replace(to_replace='United States', value=np.NaN)

# %%
death_coverage1 = death_coverage1.replace(to_replace='United States (6)', value=np.NaN)

# %%
death_coverage1
# Out:
#             county  Age-Adjusted Death Rate       Race  \
# 0              NaN                     21.6  All races
# 1              NaN                     20.7      White
# 2              NaN                     29.1      Black
# 3              NaN                     19.6  All races
# 4              NaN                     27.6      Black
# ...            ...                      ...        ...
# 1426  Wayne County                      NaN      Black
# 1427  Wayne County                      NaN      Black
# 1428  Wayne County                      NaN      Black
# 1429  Wayne County                      NaN      Black
# 1430           NaN                     19.7      White
#
#       Total – Insured Population (Female)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ...                                   ...
# ...

# %%
death_coverage1.columns = ['county', 'death-rate', 'race','insured_female', 'uninsured_female']
death_coverage1.head()
# Out:
#   county  death-rate       race  insured_female  uninsured_female
# 0    NaN        21.6  All races             NaN               NaN
# 1    NaN        20.7      White             NaN               NaN
# 2    NaN        29.1      Black             NaN               NaN
# 3    NaN        19.6  All races             NaN               NaN
# 4    NaN        27.6      Black             NaN               NaN

# %%
death_coverage1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1431 entries, 0 to 1430
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   county            1425 non-null   object
#  1   death-rate        711 non-null    float64
#  2   race              1431 non-null   object
#  3   insured_female    1425 non-null   float64
#  4   uninsured_female  1425 non-null   float64
# dtypes: float64(3), object(2)
# memory usage: 67.1+ KB

# %% [markdown]
# death_coverage1.groupby(['county']).insured_female.agg({'sum'})

# %% [markdown]
# death_coverage1[(death_coverage1['death-rate'] >= 25.0)]

# %%
death_cov2 = death_coverage1[(death_coverage1['race'] == 'All races')]
death_cov2
# Out:
#                county  death-rate       race  insured_female  uninsured_female
# 0                 NaN        21.6  All races             NaN               NaN
# 3                 NaN        19.6  All races             NaN               NaN
# 5     Crockett County        31.9  All races          6639.0             659.0
# 6     Crockett County        31.9  All races          6792.0             644.0
# 7     Crockett County        31.9  All races          6687.0             766.0
# ...               ...         ...        ...             ...               ...
# 1415     Wayne County         NaN  All races          6428.0             980.0
# 1416     Wayne County         NaN  All races          6456.0             963.0
# 1417     Wayne County         NaN  All races          6432.0             930.0
# 1418     Wayne County         NaN  All races          6463.0             889.0
# 1419     Wayne County         NaN  All races          6476.0             907.0
#
# [477 rows x 5 columns]

# %%
death_cov2.groupby(['county']).insured_female.agg({'sum'})
# Out:
#                         sum
# county
# Anderson County    175695.0
# Bedford County     105641.0
# Benton County       36289.0
# Bledsoe County      27286.0
# Blount County      297609.0
# ...                     ...
# Wayne County        32255.0
# Weakley County      76683.0
# White County        59408.0
# Williamson County  526801.0
# Wilson County      311921.0
#
# [95 rows x 1 columns]

# %% [markdown]
# death_cov2[(death_cov2['race'] == 'All races')]

# %%
plt.figure(figsize=(6, 6))

corr = death_coverage1.corr()

# create a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, cmap=cmap, mask = mask, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5});
# Out:
# C:\Users\aaust\AppData\Local\Temp\ipykernel_4328\2880681875.py:9: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(corr, dtype=np.bool)
