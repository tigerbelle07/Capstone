# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
DeathRate = pd.read_excel('../data/death.xlsx')

# %%
DeathRate
# Out:
#               County   FIPS Met Healthy People Objective of 15.3?  \
# 0          Tennessee  47000                                    No
# 1      United States      0                                    No
# 2    Crockett County  47033                                    No
# 3      Unicoi County  47171                                    No
# 4       Scott County  47151                                    No
# ..               ...    ...                                   ...
# 92      Smith County  47159                                   ***
# 93    Stewart County  47161                                   ***
# 94  Trousdale County  47169                                   ***
# 95  Van Buren County  47175                                   ***
# 96      Wayne County  47181                                   ***
#
#    Age-Adjusted Death Rate([rate note]) - deaths per 100,000 Lower CI (Rate)  \
# 0                                                21.6                     21
# ...

# %%
HealthIns_16 = pd.read_excel('../data/Health_Economics_2016.xlsx', sheet_name =('Data'))

# %%
HealthIns_16
# Out:
#                                   Unnamed: 0 Anderson County, Tennessee  \
# 0                                      Label                   Estimate
# 1                          EMPLOYMENT STATUS                        NaN
# 2               Population 16 years and over                     61,370
# 3                             In labor force                     34,409
# 4                       Civilian labor force                     34,409
# ..                                       ...                        ...
# 141                        18 years and over                        (X)
# 142                           18 to 64 years                        (X)
# 143                        65 years and over                        (X)
# 144                       People in families                        (X)
# 145  Unrelated individuals 15 years and over                        (X)
#
#           Unnamed: 2 Unnamed: 3               Unnamed: 4  \
# ...
